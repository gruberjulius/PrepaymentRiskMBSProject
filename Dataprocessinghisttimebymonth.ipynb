# %% [markdown]
# # Sorting the hist data by month

# %% [markdown]
# This file aims to create new dataset sorted over the month column for the historical times data

# %%
import pandas as pd
import os

# %%
column_names = [
    "LOAN_SEQUENCE_NUMBER", "MONTHLY_REPORTING_PERIOD", "CURRENT_ACTUAL_UPB", "CURRENT_LOAN_DELINQUENCY_STATUS",
    "LOAN_AGE", "REMAINING_MONTHS", "REPURCHASE_FLAG", "MODIFICATION_FLAG", "ZERO_BALANCE_CODE",
    "ZERO_BALANCE_EFFECTIVE_DATE", "CURRENT_INTEREST_RATE", "CURRENT_DEFERRED_UPB", "DUE_DATE_OF_LAST_PAID_INSTALLMENT",
    "MI_RECOVERIES", "NET_SALES_PROCEEDS", "NON_MI_RECOVERIES", "EXPENSES", "LEGAL_COSTS", "MAINTENANCE_AND_PRESERVATION_COSTS",
    "TAXES_AND_INSURANCE", "MISCELLANEOUS_EXPENSES", "ACTUAL_LOSS_CALCULATION", "MODIFICATION_COST", "STEP_MODIFICATION_FLAG",
    "DEFERRED_PAYMENT_MODIFICATION", "ESTIMATED_LOAN_TO_VALUE", "ZERO_BALANCE_REMOVAL_UPB", "DELINQUENT_ACCRUED_INTEREST",
    "DELINQUENCY_DUE_TO_DISASTER", "BORROWER_ASSISTANCE_STATUS_CODE", "CURRENT_MONTH_LIQUIDATION_FLAG", "CURRENT_MONTH_REPURCHASE_FLAG"
]

# %%
for year in range(2006, 2024):  # 2024 because the range end is exclusive
    print(year)
    file_path1 = f'hist_time_parquet/hist_data_time_{year}Q1.parquet'
    df1 = pd.read_parquet(file_path1)
    
     
    file_path2 = f'hist_time_parquet/hist_data_time_{year}Q2.parquet'
    df2 = pd.read_parquet(file_path2)
    
    file_path3 = f'hist_time_parquet/hist_data_time_{year}Q3.parquet'
    df3 = pd.read_parquet(file_path3)
    
    file_path4 = f'hist_time_parquet/hist_data_time_{year}Q4.parquet'
    df4 = pd.read_parquet(file_path4)
    

    df1.columns = column_names
    df2.columns = column_names
    df3.columns = column_names
    df4.columns = column_names

    big_df = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)

    
    #sort the big dataframe by months
    directory = 'hist_time_by_month'
    #append a file for each months column in this step here
    # Iterate over each group
    for name, group in big_df.groupby('MONTHLY_REPORTING_PERIOD'):
        file_path = os.path.join(directory, f'{name}.parquet')
        
        if os.path.exists(file_path):
            # Read the existing data
            existing_data = pd.read_parquet(file_path)
            
            # Concatenate the new data
            updated_data = pd.concat([existing_data, group], ignore_index=True)
        else:
            updated_data = group
        
        # Write (or overwrite) the Parquet file
        updated_data.to_parquet(file_path, engine='pyarrow', index=False)
# Out:
# 2006
# 2007
# 2008
# 2009

# %%
big_df
# Out:
#          LOAN_SEQUENCE_NUMBER  MONTHLY_REPORTING_PERIOD  CURRENT_ACTUAL_UPB  \
# 0                F06Q10000001                    200604           130000.00
# 1                F06Q10000001                    200605           130000.00
# 2                F06Q10000001                    200606           130000.00
# 3                F06Q10000001                    200607           129000.00
# 4                F06Q10000001                    200608           129000.00
# ...                       ...                       ...                 ...
# 75564097         F06Q40433172                    202305           158773.22
# 75564098         F06Q40433172                    202306           157800.24
# 75564099         F06Q40433172                    202307           156821.99
# 75564100         F06Q40433172                    202308           155838.44
# 75564101         F06Q40433172                    202309           154849.56
#
#          CURRENT_LOAN_DELINQUENCY_STATUS  LOAN_AGE  REMAINING_MONTHS  \
# 0                                      0         1               359
# 1                                      0         2               358
# 2                                      0         3               357
# 3                                      0         4               356
# 4                                      0         5               355
# ...                                  ...       ...               ...
# 75564097                               0       196               164
# 75564098                               0       197               163
# 75564099                               0       198               162
# 75564100                               0       199               161
# 75564101                               0       200               160
#
#           REPURCHASE_FLAG MODIFICATION_FLAG  ZERO_BALANCE_CODE  \
# 0                     NaN              None                NaN
# 1                     NaN              None                NaN
# 2                     NaN              None                NaN
# 3                     NaN              None                NaN
# 4                     NaN              None                NaN
# ...                   ...               ...                ...
# 75564097              NaN              None                NaN
# 75564098              NaN              None                NaN
# 75564099              NaN              None                NaN
# 75564100              NaN              None                NaN
# 75564101              NaN              None                NaN
#
#           ZERO_BALANCE_EFFECTIVE_DATE  ...  MODIFICATION_COST  \
# 0                                 NaN  ...                NaN
# 1                                 NaN  ...                NaN
# 2                                 NaN  ...                NaN
# 3                                 NaN  ...                NaN
# 4                                 NaN  ...                NaN
# ...                               ...  ...                ...
# 75564097                          NaN  ...                NaN
# 75564098                          NaN  ...                NaN
# 75564099                          NaN  ...                NaN
# 75564100                          NaN  ...                NaN
# 75564101                          NaN  ...                NaN
#
#           STEP_MODIFICATION_FLAG  DEFERRED_PAYMENT_MODIFICATION  \
# 0                           None                           None
# 1                           None                           None
# 2                           None                           None
# 3                           None                           None
# 4                           None                           None
# ...                          ...                            ...
# 75564097                    None                           None
# 75564098                    None                           None
# 75564099                    None                           None
# 75564100                    None                           None
# 75564101                    None                           None
#
#           ESTIMATED_LOAN_TO_VALUE  ZERO_BALANCE_REMOVAL_UPB  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 75564097                     22.0                       NaN
# 75564098                     23.0                       NaN
# 75564099                     21.0                       NaN
# 75564100                     21.0                       NaN
# 75564101                     22.0                       NaN
#
#           DELINQUENT_ACCRUED_INTEREST  DELINQUENCY_DUE_TO_DISASTER  \
# 0                                 NaN                         None
# 1                                 NaN                         None
# 2                                 NaN                         None
# 3                                 NaN                         None
# 4                                 NaN                         None
# ...                               ...                          ...
# 75564097                          NaN                         None
# 75564098                          NaN                         None
# 75564099                          NaN                         None
# 75564100                          NaN                         None
# 75564101                          NaN                         None
#
#           BORROWER_ASSISTANCE_STATUS_CODE  CURRENT_MONTH_LIQUIDATION_FLAG  \
# 0                                    None                             NaN
# 1                                    None                             NaN
# 2                                    None                             NaN
# 3                                    None                             NaN
# 4                                    None                             NaN
# ...                                   ...                             ...
# 75564097                             None                             NaN
# 75564098                             None                             NaN
# 75564099                             None                             NaN
# 75564100                             None                             NaN
# 75564101                             None                             NaN
#
#           CURRENT_MONTH_REPURCHASE_FLAG
# 0                             130000.00
# 1                             130000.00
# 2                             130000.00
# 3                             129000.00
# 4                             129000.00
# ...                                 ...
# 75564097                      158773.22
# 75564098                      157800.24
# 75564099                      156821.99
# 75564100                      155838.44
# 75564101                      154849.56
#
# [75564102 rows x 32 columns]

# %%
# %%time
big_df.sort_values(by='MONTHLY_REPORTING_PERIOD', inplace=True)
# Out:
# CPU times: user 8.23 s, sys: 5.37 s, total: 13.6 s
# Wall time: 17.3 s

# %%
# Iterate over each group
for name, group in big_df.groupby('MONTHLY_REPORTING_PERIOD'):
    # File path using the name of the reporting period
    file_path = f'/{name}.parquet'  # Modify the path as needed

    # Save each group to a separate Parquet file
    group.to_parquet(file_path, engine='pyarrow', index=False)  # index=False if you don't want to save the index
# Out:
#          LOAN_SEQUENCE_NUMBER  MONTHLY_REPORTING_PERIOD  CURRENT_ACTUAL_UPB  \
# 156166           F06Q10002886                    200601                0.00
# 70465            F06Q10001123                    200601                0.00
# 5413459          F06Q10098149                    200602           178000.00
# 1190904          F06Q10020644                    200602            80000.00
# 790511           F06Q10013533                    200602           212000.00
# ...                       ...                       ...                 ...
# 30925346         F06Q20228402                    202309            54990.49
# 871492           F06Q10015162                    202309            40609.40
# 55474544         F06Q30374623                    202309            81657.79
# 63687411         F06Q40164801                    202309            21670.23
# 75564101         F06Q40433172                    202309           154849.56
#
#          CURRENT_LOAN_DELINQUENCY_STATUS  LOAN_AGE  REMAINING_MONTHS  \
# 156166                                 0         0               360
# 70465                                  0         0               180
# 5413459                                0         0               360
# 1190904                                0         0               360
# 790511                                 0         0               360
# ...                                  ...       ...               ...
# 30925346                               0       207               153
# 871492                                 0       209               151
# 55474544                               0       203               157
# 63687411                               0       201               159
# 75564101                               0       200               160
#
#           REPURCHASE_FLAG MODIFICATION_FLAG  ZERO_BALANCE_CODE  \
# 156166                NaN              None                1.0
# 70465                 NaN              None                1.0
# 5413459               NaN              None                NaN
# 1190904               NaN              None                NaN
# 790511                NaN              None                NaN
# ...                   ...               ...                ...
# 30925346              NaN              None                NaN
# 871492                NaN              None                NaN
# 55474544              NaN              None                NaN
# 63687411              NaN              None                NaN
# 75564101              NaN              None                NaN
#
#           ZERO_BALANCE_EFFECTIVE_DATE  ...  MODIFICATION_COST  \
# 156166                       200601.0  ...                NaN
# 70465                        200601.0  ...                NaN
# 5413459                           NaN  ...                NaN
# 1190904                           NaN  ...                NaN
# 790511                            NaN  ...                NaN
# ...                               ...  ...                ...
# 30925346                          NaN  ...                NaN
# 871492                            NaN  ...                NaN
# 55474544                          NaN  ...                NaN
# 63687411                          NaN  ...                NaN
# 75564101                          NaN  ...                NaN
#
#           STEP_MODIFICATION_FLAG  DEFERRED_PAYMENT_MODIFICATION  \
# 156166                      None                           None
# 70465                       None                           None
# 5413459                     None                           None
# 1190904                     None                           None
# 790511                      None                           None
# ...                          ...                            ...
# 30925346                    None                           None
# 871492                      None                           None
# 55474544                    None                           None
# 63687411                    None                           None
# 75564101                    None                           None
#
#           ESTIMATED_LOAN_TO_VALUE  ZERO_BALANCE_REMOVAL_UPB  \
# 156166                        NaN                  151000.0
# 70465                         NaN                  100000.0
# 5413459                       NaN                       NaN
# 1190904                       NaN                       NaN
# 790511                        NaN                       NaN
# ...                           ...                       ...
# 30925346                    999.0                       NaN
# 871492                       20.0                       NaN
# 55474544                    999.0                       NaN
# 63687411                     29.0                       NaN
# 75564101                     22.0                       NaN
#
#           DELINQUENT_ACCRUED_INTEREST  DELINQUENCY_DUE_TO_DISASTER  \
# 156166                            NaN                         None
# 70465                             NaN                         None
# 5413459                           NaN                         None
# 1190904                           NaN                         None
# 790511                            NaN                         None
# ...                               ...                          ...
# 30925346                          NaN                         None
# 871492                            NaN                         None
# 55474544                          NaN                         None
# 63687411                          NaN                         None
# 75564101                          NaN                         None
#
#           BORROWER_ASSISTANCE_STATUS_CODE  CURRENT_MONTH_LIQUIDATION_FLAG  \
# 156166                               None                             NaN
# 70465                                None                             NaN
# 5413459                              None                             NaN
# 1190904                              None                             NaN
# 790511                               None                             NaN
# ...                                   ...                             ...
# 30925346                             None                             NaN
# 871492                               None                             NaN
# 55474544                             None                             NaN
# 63687411                             None                             NaN
# 75564101                             None                             NaN
#
#           CURRENT_MONTH_REPURCHASE_FLAG
# 156166                             0.00
# 70465                              0.00
# 5413459                       178000.00
# 1190904                        80000.00
# 790511                        212000.00
# ...                                 ...
# 30925346                       54990.49
# 871492                         40609.40
# 55474544                       81657.79
# 63687411                       21670.23
# 75564101                      154849.56
#
# [75564102 rows x 32 columns]

# %%
import pandas as pd
import os

# Directory where Parquet files are stored
directory = 'hist_time_by_month'

# Iterate over each group
for name, group in big_df.groupby('MONTHLY_REPORTING_PERIOD'):
    file_path = os.path.join(directory, f'{name}.parquet')
    
    if os.path.exists(file_path):
        # Read the existing data
        existing_data = pd.read_parquet(file_path)
        
        # Concatenate the new data
        updated_data = pd.concat([existing_data, group], ignore_index=True)
    else:
        updated_data = group
    
    # Write (or overwrite) the Parquet file
    updated_data.to_parquet(file_path, engine='pyarrow', index=False)

# %%
file_path1 = f'hist_time_parquet/hist_data_time_2006Q1.parquet'
df1 = pd.read_parquet(file_path1)

# %%
file_path1 = f'hist_time_by_month/200602.parquet'
df1 = pd.read_parquet(file_path1)

# %%
df1
# Out:
#       LOAN_SEQUENCE_NUMBER  MONTHLY_REPORTING_PERIOD  CURRENT_ACTUAL_UPB  \
# 0             F06Q10098149                    200602            178000.0
# 1             F06Q10020644                    200602             80000.0
# 2             F06Q10013533                    200602            212000.0
# 3             F06Q10017610                    200602            144000.0
# 4             F06Q10011269                    200602            132000.0
# ...                    ...                       ...                 ...
# 71045         F06Q10052925                    200602            272000.0
# 71046         F06Q10065294                    200602            119000.0
# 71047         F06Q10052920                    200602            291000.0
# 71048         F06Q10052921                    200602            340000.0
# 71049         F06Q10065274                    200602            146000.0
#
#       CURRENT_LOAN_DELINQUENCY_STATUS  LOAN_AGE  REMAINING_MONTHS  \
# 0                                   0         0               360
# 1                                   0         0               360
# 2                                   0         0               360
# 3                                   0         0               360
# 4                                   0         0               360
# ...                               ...       ...               ...
# 71045                               0         0               360
# 71046                               0         0               360
# 71047                               0         0               360
# 71048                               0         0               360
# 71049                               0         0               360
#
#        REPURCHASE_FLAG MODIFICATION_FLAG  ZERO_BALANCE_CODE  \
# 0                  NaN              None                NaN
# 1                  NaN              None                NaN
# 2                  NaN              None                NaN
# 3                  NaN              None                NaN
# 4                  NaN              None                NaN
# ...                ...               ...                ...
# 71045              NaN              None                NaN
# 71046              NaN              None                NaN
# 71047              NaN              None                NaN
# 71048              NaN              None                NaN
# 71049              NaN              None                NaN
#
#        ZERO_BALANCE_EFFECTIVE_DATE  ...  MODIFICATION_COST  \
# 0                              NaN  ...                NaN
# 1                              NaN  ...                NaN
# 2                              NaN  ...                NaN
# 3                              NaN  ...                NaN
# 4                              NaN  ...                NaN
# ...                            ...  ...                ...
# 71045                          NaN  ...                NaN
# 71046                          NaN  ...                NaN
# 71047                          NaN  ...                NaN
# 71048                          NaN  ...                NaN
# 71049                          NaN  ...                NaN
#
#        STEP_MODIFICATION_FLAG  DEFERRED_PAYMENT_MODIFICATION  \
# 0                        None                           None
# 1                        None                           None
# 2                        None                           None
# 3                        None                           None
# 4                        None                           None
# ...                       ...                            ...
# 71045                    None                           None
# 71046                    None                           None
# 71047                    None                           None
# 71048                    None                           None
# 71049                    None                           None
#
#        ESTIMATED_LOAN_TO_VALUE  ZERO_BALANCE_REMOVAL_UPB  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 71045                      NaN                       NaN
# 71046                      NaN                       NaN
# 71047                      NaN                       NaN
# 71048                      NaN                       NaN
# 71049                      NaN                       NaN
#
#        DELINQUENT_ACCRUED_INTEREST  DELINQUENCY_DUE_TO_DISASTER  \
# 0                              NaN                         None
# 1                              NaN                         None
# 2                              NaN                         None
# 3                              NaN                         None
# 4                              NaN                         None
# ...                            ...                          ...
# 71045                          NaN                         None
# 71046                          NaN                         None
# 71047                          NaN                         None
# 71048                          NaN                         None
# 71049                          NaN                         None
#
#        BORROWER_ASSISTANCE_STATUS_CODE  CURRENT_MONTH_LIQUIDATION_FLAG  \
# 0                                 None                             NaN
# 1                                 None                             NaN
# 2                                 None                             NaN
# 3                                 None                             NaN
# 4                                 None                             NaN
# ...                                ...                             ...
# 71045                             None                             NaN
# 71046                             None                             NaN
# 71047                             None                             NaN
# 71048                             None                             NaN
# 71049                             None                             NaN
#
#        CURRENT_MONTH_REPURCHASE_FLAG
# 0                           178000.0
# 1                            80000.0
# 2                           212000.0
# 3                           144000.0
# 4                           132000.0
# ...                              ...
# 71045                       272000.0
# 71046                       119000.0
# 71047                       291000.0
# 71048                       340000.0
# 71049                       146000.0
#
# [71050 rows x 32 columns]

# %%
# !ls
# Out:
# Data_Cleaning_For_Static_Set.ipynb    Untitled.ipynb
# HistoricalTimeDataAnalysis.ipynb      UselessFiles
# Historical_Data_Prep.ipynb            data
# Interest_rate_data_monthly.csv        hist_time_parquet
# Prepayments_against_rate_and_time.png parquet_compression_hist_time.ipynb
# PrepaymentsbyMonth.png                playground.ipynb
# PrepaymentsbyMonthCutOff.png

# %% [markdown]
# # Sample

# %%
file_path1 = f'/Users/juliusgruber/Downloads/historical_data_2006/historical_data_time_2006Q1.txt'
df1 = pd.read_csv(file_path1, sep='|', low_memory=False)

# %%
df1
# Out:
#           F06Q10000001  200603  130000.00  0  000  360  Unnamed: 6 Unnamed: 7  \
# 0         F06Q10000001  200604  130000.00  0    1  359         NaN        NaN
# 1         F06Q10000001  200605  130000.00  0    2  358         NaN        NaN
# 2         F06Q10000001  200606  130000.00  0    3  357         NaN        NaN
# 3         F06Q10000001  200607  129000.00  0    4  356         NaN        NaN
# 4         F06Q10000001  200608  129000.00  0    5  355         NaN        NaN
# ...                ...     ...        ... ..  ...  ...         ...        ...
# 20379138  F06Q10374577  202004   44394.76  1   53  191         NaN        NaN
# 20379139  F06Q10374577  202005   44394.76  2   54  190         NaN        NaN
# 20379140  F06Q10374577  202006   44394.76  3   55  189         NaN        NaN
# 20379141  F06Q10374577  202007   44394.76  4   56  188         NaN        NaN
# 20379142  F06Q10374577  202008       0.00  0   57  187    202009.0        NaN
#
#           Unnamed: 8  Unnamed: 9  ...  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0                NaN         NaN  ...          NaN          NaN          NaN
# 1                NaN         NaN  ...          NaN          NaN          NaN
# 2                NaN         NaN  ...          NaN          NaN          NaN
# 3                NaN         NaN  ...          NaN          NaN          NaN
# 4                NaN         NaN  ...          NaN          NaN          NaN
# ...              ...         ...  ...          ...          ...          ...
# 20379138         NaN         NaN  ...          NaN          NaN          NaN
# 20379139         NaN         NaN  ...          NaN          NaN          NaN
# 20379140         NaN         NaN  ...          NaN          NaN          NaN
# 20379141         NaN         NaN  ...          NaN          NaN          NaN
# 20379142        96.0    202009.0  ...          NaN          NaN          NaN
#
#           Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  \
# 0                 NaN          NaN          NaN          NaN          NaN
# 1                 NaN          NaN          NaN          NaN          NaN
# 2                 NaN          NaN          NaN          NaN          NaN
# 3                 NaN          NaN          NaN          NaN          NaN
# 4                 NaN          NaN          NaN          NaN          NaN
# ...               ...          ...          ...          ...          ...
# 20379138         17.0          NaN          NaN          NaN          NaN
# 20379139         16.0          NaN          NaN            Y          NaN
# 20379140         16.0          NaN          NaN            Y          NaN
# 20379141         16.0          NaN          NaN            Y          NaN
# 20379142         16.0     44394.76          NaN          NaN          NaN
#
#           Unnamed: 30  130000.00.1
# 0                 NaN    130000.00
# 1                 NaN    130000.00
# 2                 NaN    130000.00
# 3                 NaN    129000.00
# 4                 NaN    129000.00
# ...               ...          ...
# 20379138          NaN     44394.76
# 20379139          NaN     44394.76
# 20379140          NaN     44394.76
# 20379141          NaN     44394.76
# 20379142          NaN         0.00
#
# [20379143 rows x 32 columns]
